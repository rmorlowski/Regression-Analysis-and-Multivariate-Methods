# %%
#import some packages you will be using
import pandas as pd
import pandas_profiling
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf  
import matplotlib.pyplot as plt 
from scipy import stats
from sklearn import linear_model, metrics
 
get_ipython().magic(u'matplotlib inline')
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#set some options for the output
pd.set_option('display.notebook_repr_html', False) 
pd.set_option('display.max_columns', 40) 
pd.set_option('display.max_rows', 10) 
pd.set_option('display.width', 120)

# %%
#read in the datasets
train = pd.read_csv('/Users/rmorlows/Desktop/MSDS410/Assignment 01/AMES_TRAIN.csv')
test = pd.read_csv('/Users/rmorlows/Desktop/MSDS410/Assignment 01/AMES_TEST_SFAM.csv')

# %%
#A good step to take is to convert all variable names to lower case
train.columns = [s.lower() for s in train.columns]
test.columns = [s.lower() for s in test.columns]

# %%
#do some exploration of the data
print('')
print('----- Summary of Train Data -----')
print('')
#pandas_profiling.ProfileReport(train)
# Out:
# ----- Summary of Train Data -----

# %%
# show the object is a DataFrame
print('Object type: ', type(train))
# Out:
# Object type:  <class 'pandas.core.frame.DataFrame'>

# %%
# show number of observations in the DataFrame
print('Number of observations: ', len(train))
# Out:
# Number of observations:  2039

# %%
# show variable names
print('Variable names: ', train.columns)
# Out:
# Variable names:  Index(['subclass', 'zoning', 'lotfrontage', 'lotarea', 'street', 'alley', 'lotshape', 'landcontour', 'utilities',
#        'lotconfig', 'landslope', 'neighborhood', 'condition1', 'condition2', 'bldgtype', 'housestyle', 'overallqual',
#        'overallcond', 'yearbuilt', 'yearremodel', 'roofstyle', 'roofmat', 'exterior1', 'exterior2', 'masvnrtype',
#        'masvnrarea', 'exterqual', 'extercond', 'foundation', 'bsmtqual', 'bsmtcond', 'bsmtexposure', 'bsmtfintype1',
#        'bsmtfinsf1', 'bsmtfintype2', 'bsmtfinsf2', 'bsmtunfsf', 'totalbsmtsf', 'heating', 'heatingqc', 'centralair',
#        'electrical', 'firstflrsf', 'secondflrsf', 'lowqualfinsf', 'grlivarea', 'bsmtfullbath', 'bsmthalfbath',
#        'fullbath', 'halfbath', 'bedroomabvgr', 'kitchenabvgr', 'kitchenqual', 'totrmsabvgrd', 'functional',
#        'fireplaces', 'fireplacequ', 'garagetype', 'garageyrblt', 'garagefinish', 'garagecars', 'garagearea',
#        'garagequal', 'garagecond', 'paveddrive', 'wooddecksf', 'openporchsf', 'enclosedporch', 'threessnporch',
#        'screenporch', 'poolarea', 'poolqc', 'fence', 'miscfeature', 'miscval', 'mosold', 'yrsold', 'saletype',
#        'salecondition', 'saleprice', 'index'],
#       dtype='object')

# %%
#Do we have missing values? 
datasetHasNan = False
if train.count().min() == train.shape[0] and test.count().min() == test.shape[0] :
    print('We do not need to worry about missing values.') 
else:
    datasetHasNan = True
    print('oops we have nan')
# Out:
# oops we have nan

# %%
print('----train dataset column types information-------')
dtype_df = train.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
dtype_df.groupby("Column Type").aggregate('count').reset_index()
# Out:
# ----train dataset column types information-------
#   Column Type  Count
# 0       int64     29
# 1     float64      9
# 2      object     43

# %%
#Check for missing data & list them 
if datasetHasNan == True:
    nas = pd.concat([train.isnull().sum(), test.isnull().sum()], axis=1, keys=['Train Dataset', 'Test Dataset']) 
    print('Nan in the data sets')
    print(nas[nas.sum(axis=1) > 0])
# Out:
# Nan in the data sets
#               Train Dataset  Test Dataset
# alley                1893.0           690
# bsmtcond               54.0            12
# bsmtexposure           56.0            13
# bsmtfinsf1              1.0             0
# bsmtfinsf2              1.0             0
# ...                     ...           ...
# miscfeature          1963.0           698
# p_saleprice             NaN           726
# poolqc               2028.0           724
# saleprice               0.0           726
# totalbsmtsf             1.0             0
#
# [29 rows x 2 columns]

# %%
# show a portion of the beginning of the DataFrame
print(train.head())
# Out:
#    subclass zoning  lotfrontage  lotarea street alley lotshape landcontour utilities lotconfig landslope neighborhood  \
# 0        20     RL          NaN    11838   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1        60     RL         70.0     8304   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl      SawyerW
# 2        45     RM         58.0     6380   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl      BrkSide
# 3        60     RL          NaN    14803   Pave   NaN      IR1         Lvl    AllPub   CulDSac       Gtl       NWAmes
# 4        20     RL         91.0    11375   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl       Sawyer
#
#   condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodel  ...  garagearea  \
# 0       Norm       Norm     1Fam     1Story            8            5       2001         2001  ...         522
# 1       Norm       Norm     1Fam     2Story            6            5       1997         1998  ...         688
# 2       Norm       Norm     1Fam     1.5Unf            5            6       1922         1950  ...         280
# 3       Norm       Norm     1Fam     2Story            6            5       1971         1971  ...         495
# 4       Norm       Norm     1Fam     1Story            6            5       1954         1995  ...         494
#
#   garagequal garagecond paveddrive wooddecksf  openporchsf enclosedporch threessnporch screenporch poolarea poolqc  \
# 0         TA         TA          Y        202          151             0             0           0        0    NaN
# 1         TA         TA          Y        150          165             0             0           0        0    NaN
# 2         TA         TA          Y          0            0           116             0           0        0    NaN
# 3         TA         TA          Y          0           66             0             0           0        0    NaN
# 4         TA         TA          Y         81            0           280             0           0        0    NaN
#
#    fence miscfeature  miscval mosold  yrsold  saletype  salecondition saleprice index
# 0    NaN         NaN        0      6    2009        WD         Normal    236500     2
# 1  GdPrv         NaN        0      7    2006        WD         Normal    187000     3
# 2    NaN         NaN        0      8    2006        WD         Normal    113000     5
# 3   GdWo         NaN        0      6    2006        WD         Normal    190000     6
# 4    NaN         NaN        0     10    2007        WD         Normal    150000     8
#
# [5 rows x 81 columns]

# %%
#watch your record count and fix records with missing NaN data
print (train.shape)
train.isnull().sum()
train[train == 0].count()
# Out:
# (2039, 81)
# subclass         0
# zoning           0
# lotfrontage      0
# lotarea          0
# street           0
#                 ..
# yrsold           0
# saletype         0
# salecondition    0
# saleprice        0
# index            0
# Length: 81, dtype: int64

# %%
#Fill missing values with NA per data dictionary
train.loc[:, "alley"] = train.loc[:, "alley"].fillna("NA")
train.loc[:, "bsmtcond"] = train.loc[:, "bsmtcond"].fillna("NA")
train.loc[:, "bsmtexposure"] = train.loc[:, "bsmtexposure"].fillna("NA")
train.loc[:, "bsmtfintype1"] = train.loc[:, "bsmtfintype1"].fillna("NA")
train.loc[:, "bsmtfintype2"] = train.loc[:, "bsmtfintype2"].fillna("NA")
train.loc[:, "bsmtqual"] = train.loc[:, "bsmtqual"].fillna("NA")
train.loc[:, "fence"] = train.loc[:, "fence"].fillna("NA")
train.loc[:, "fireplacequ"] = train.loc[:, "fireplacequ"].fillna("NA")
train.loc[:, "garagecond"] = train.loc[:, "garagecond"].fillna("NA")
train.loc[:, "garagefinish"] = train.loc[:, "garagefinish"].fillna("NA")
train.loc[:, "garagequal"] = train.loc[:, "garagequal"].fillna("NA")
train.loc[:, "garagetype"] = train.loc[:, "garagetype"].fillna("NA")
train.loc[:, "miscfeature"] = train.loc[:, "miscfeature"].fillna("NA")
train.loc[:, "poolqc"] = train.loc[:, "poolqc"].fillna("NA")

#most common value
train.loc[:, "electrical"] = train.loc[:, "electrical"].fillna("SBrkr")
train.loc[:, "masvnrtype"] = train.loc[:, "masvnrtype"].fillna("None")

# handle missing values for features where median/mean or most common value doesn't make sense
train.loc[:, "bsmtfullbath"] = train.loc[:, "bsmtfullbath"].fillna(0)
train.loc[:, "bsmthalfbath"] = train.loc[:, "bsmthalfbath"].fillna(0)
train.loc[:, "bsmtunfsf"] = train.loc[:, "bsmtunfsf"].fillna(0)
train.loc[:, "bsmtfinsf1"] = train.loc[:, "bsmtfinsf1"].fillna(0)
train.loc[:, "bsmtfinsf2"] = train.loc[:, "bsmtfinsf2"].fillna(0)
train.loc[:, "masvnrarea"] = train.loc[:, "masvnrarea"].fillna(0)

# %%
#Replace NaN values with medians in train data
train=train.replace({'lotfrontage': {np.NaN : 50}})
train=train.replace({'garageyrblt': {np.NaN : 1972}})
train=train.replace({'totalbsmtsf': {np.NaN : 975}})

# %%
#Convert ordinal variables to numbers per data dictionary
train = train.replace({"bsmtcond" : {"NA" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "bsmtqual" : {"NA" : 0, "Po" : 1, "Fa" : 2, "TA": 3, "Gd" : 4, "Ex" : 5},
                       "bsmtexposure" : {"NA" : 0,"No" : 1, "Mn" : 2, "Av": 3, "Gd" : 4},
                       "bsmtfintype1" : {"NA" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4,
                                         "ALQ" : 5, "GLQ" : 6},
                       "bsmtfintype2" : {"NA" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4,
                                         "ALQ" : 5, "GLQ" : 6},
                       "electrical" : {"Mix" : 1, "FuseP" : 2, "FuseF": 3, "FusA": 4, "SBrkr" : 5},
                       "extercond" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "exterqual" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "fence" : {"NA" : 0, "MnWw" : 1, "GdWo": 2, "MnPrv": 3, "GdPrv" : 4},
                       "fireplacequ" : {"NA" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "functional" : {"Sal" : 1, "Sev" : 2, "Maj" : 3, "Mod": 4, "Min"  : 5, "Typ" : 6},
                       "garagefinish" : {"NA" : 0, "Unf" : 1, "RFn" : 2, "Fin" : 3},
                       "garagecond" : {"NA" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "garagequal" : {"NA" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "heatingqc" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "kitchenqual" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "landslope" : {"Sev" : 1, "Mod" : 2, "Gtl" : 3},
                       "lotshape" : {"IR3" : 1, "IR2" : 2, "IR1" : 3, "Reg" : 4},
                       "paveddrive" : {"N" : 0, "P" : 1, "Y" : 2},
                       "poolqc" : {"NA" : 0, "Fa" : 1, "TA" : 2, "Gd" : 3, "Ex" : 4},
                       "utilities" : {"ELO" : 1, "NoSeWa" : 2, "NoSewr" : 3, "AllPub" : 4}}
                     )

# %%
#CHECK CLEAN DATA
#pandas_profiling.ProfileReport(train)

# %%
# show descriptive statistics
print(train.describe())
# Out:
#           subclass  lotfrontage        lotarea     lotshape    utilities    landslope  overallqual  overallcond  \
# count  2039.000000  2039.000000    2039.000000  2039.000000  2039.000000  2039.000000  2039.000000  2039.000000
# mean     56.586562    65.619912   10062.990191     3.612555     3.998529     2.948014     6.077979     5.585091
# std      41.876919    22.206238    8125.002560     0.555956     0.049510     0.243149     1.407362     1.107337
# min      20.000000    21.000000    1477.000000     1.000000     2.000000     1.000000     1.000000     1.000000
# 25%      20.000000    50.000000    7365.000000     3.000000     4.000000     3.000000     5.000000     5.000000
# 50%      50.000000    62.000000    9320.000000     4.000000     4.000000     3.000000     6.000000     5.000000
# 75%      70.000000    78.000000   11424.500000     4.000000     4.000000     3.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000     4.000000     4.000000     3.000000    10.000000     9.000000
#
#          yearbuilt  yearremodel   masvnrarea    exterqual    extercond     bsmtqual     bsmtcond  bsmtexposure  \
# count  2039.000000  2039.000000  2039.000000  2039.000000  2039.000000  2039.000000  2039.000000   2039.000000
# mean   1970.817558  1984.100539    99.806768     3.396763     3.087298     3.467876     2.923492      1.624816
# std      30.456005    21.101772   178.931177     0.581873     0.362943     0.901325     0.564776      1.069697
# min    1872.000000  1950.000000     0.000000     2.000000     2.000000     0.000000     0.000000      0.000000
# 25%    1952.500000  1965.000000     0.000000     3.000000     3.000000     3.000000     3.000000      1.000000
# 50%    1972.000000  1993.000000     0.000000     3.000000     3.000000     3.000000     3.000000      1.000000
# 75%    2000.000000  2004.000000   157.000000     4.000000     3.000000     4.000000     3.000000      2.000000
# max    2010.000000  2010.000000  1378.000000     5.000000     5.000000     5.000000     5.000000      4.000000
#
#        bsmtfintype1   bsmtfinsf1  bsmtfintype2   bsmtfinsf2     ...       garageyrblt  garagefinish   garagecars  \
# count   2039.000000  2039.000000   2039.000000  2039.000000     ...       2039.000000   2039.000000  2039.000000
# mean       3.542423   442.463953      1.291319    49.121138     ...       1977.547818      1.699853     1.748406
# std        2.118668   457.698139      0.985906   166.648992     ...         25.181238      0.900962     0.764757
# min        0.000000     0.000000      0.000000     0.000000     ...       1895.000000      0.000000     0.000000
# 25%        1.000000     0.000000      1.000000     0.000000     ...       1961.000000      1.000000     1.000000
# 50%        4.000000   370.000000      1.000000     0.000000     ...       1977.000000      2.000000     2.000000
# 75%        6.000000   733.500000      1.000000     0.000000     ...       2001.000000      2.000000     2.000000
# max        6.000000  5644.000000      6.000000  1526.000000     ...       2207.000000      3.000000     5.000000
#
#         garagearea   garagequal   garagecond   paveddrive   wooddecksf  openporchsf  enclosedporch  threessnporch  \
# count  2039.000000  2039.000000  2039.000000  2039.000000  2039.000000  2039.000000    2039.000000    2039.000000
# mean    468.216282     2.787151     2.797450     1.821972    92.926435    46.414419      22.353114       2.454635
# std     217.054485     0.735882     0.733787     0.550838   124.988245    66.288152      61.723972      23.727244
# min       0.000000     0.000000     0.000000     0.000000     0.000000     0.000000       0.000000       0.000000
# 25%     314.000000     3.000000     3.000000     2.000000     0.000000     0.000000       0.000000       0.000000
# 50%     477.000000     3.000000     3.000000     2.000000     0.000000    25.000000       0.000000       0.000000
# 75%     576.000000     3.000000     3.000000     2.000000   168.000000    68.000000       0.000000       0.000000
# max    1488.000000     5.000000     5.000000     2.000000   870.000000   742.000000     584.000000     407.000000
#
#        screenporch     poolarea       poolqc        fence       miscval       mosold       yrsold      saleprice  \
# count  2039.000000  2039.000000  2039.000000  2039.000000   2039.000000  2039.000000  2039.000000    2039.000000
# mean     15.097106     2.751349     0.016184     0.584110     43.998038     6.267288  2007.815596  179368.827857
# std      53.478549    39.898811     0.230698     1.223206    408.502250     2.733262     1.315467   78982.943661
# min       0.000000     0.000000     0.000000     0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000     0.000000     0.000000     0.000000      0.000000     4.000000  2007.000000  128500.000000
# 50%       0.000000     0.000000     0.000000     0.000000      0.000000     6.000000  2008.000000  160000.000000
# 75%       0.000000     0.000000     0.000000     0.000000      0.000000     8.000000  2009.000000  210125.000000
# max     576.000000   800.000000     4.000000     4.000000  12500.000000    12.000000  2010.000000  745000.000000
#
#              index
# count  2039.000000
# mean   1486.918097
# std     850.390251
# min       2.000000
# 25%     746.500000
# 50%    1501.000000
# 75%    2235.500000
# max    2930.000000
#
# [8 rows x 58 columns]

# %%
# show a portion of the beginning of the clean DataFrame
print(train.head())
# Out:
#    subclass zoning  lotfrontage  lotarea street alley  lotshape landcontour  utilities lotconfig  landslope  \
# 0        20     RL         50.0    11838   Pave    NA         4         Lvl          4    Inside          3
# 1        60     RL         70.0     8304   Pave    NA         3         Lvl          4    Inside          3
# 2        45     RM         58.0     6380   Pave    NA         4         Lvl          4    Inside          3
# 3        60     RL         50.0    14803   Pave    NA         3         Lvl          4   CulDSac          3
# 4        20     RL         91.0    11375   Pave    NA         4         Lvl          4    Inside          3
#
#   neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodel  ...    \
# 0      CollgCr       Norm       Norm     1Fam     1Story            8            5       2001         2001  ...
# 1      SawyerW       Norm       Norm     1Fam     2Story            6            5       1997         1998  ...
# 2      BrkSide       Norm       Norm     1Fam     1.5Unf            5            6       1922         1950  ...
# 3       NWAmes       Norm       Norm     1Fam     2Story            6            5       1971         1971  ...
# 4       Sawyer       Norm       Norm     1Fam     1Story            6            5       1954         1995  ...
#
#   garagearea garagequal garagecond paveddrive wooddecksf  openporchsf  enclosedporch  threessnporch screenporch  \
# 0        522          3          3          2        202          151              0              0           0
# 1        688          3          3          2        150          165              0              0           0
# 2        280          3          3          2          0            0            116              0           0
# 3        495          3          3          2          0           66              0              0           0
# 4        494          3          3          2         81            0            280              0           0
#
#    poolarea  poolqc  fence  miscfeature  miscval  mosold  yrsold  saletype  salecondition saleprice  index
# 0         0       0      0           NA        0       6    2009        WD         Normal    236500      2
# 1         0       0      4           NA        0       7    2006        WD         Normal    187000      3
# 2         0       0      0           NA        0       8    2006        WD         Normal    113000      5
# 3         0       0      2           NA        0       6    2006        WD         Normal    190000      6
# 4         0       0      0           NA        0      10    2007        WD         Normal    150000      8
#
# [5 rows x 81 columns]

# %%
print('')
print('----- EDA of Train Data: Continuous Variable Analysis -----')
print('')
# Out:
# ----- EDA of Train Data: Continuous Variable Analysis -----

# %%
# Joint Distribution Plot of grlivarea
sns.jointplot(x='grlivarea', y='saleprice', data=train, kind="reg")

# %%
#Remove outliers 'any houses with more than 4000 square feet' from the dataset
train = train[train.grlivarea < 4000]

# %%
# How big are houses? (After removing outliers <4000)
print('The average house has {:,.0f} sq ft of space, the median {:,.0f} sq ft'.format(
    train.grlivarea.mean(), train.grlivarea.median()))
print('The biggest house has {:,.0f} sq ft of space, the smallest {:,.0f} sq ft'.format(
    train.grlivarea.max(), train.grlivarea.min()))
train.grlivarea.hist(bins=21, rwidth=.8, figsize=(8,4))
plt.title('How big are houses? (in sq feet)')
plt.show()
# Out:
# The average house has 1,480 sq ft of space, the median 1,430 sq ft
# The biggest house has 3,820 sq ft of space, the smallest 407 sq ft

# %%
# Joint Distribution Plot of lotfrontage
sns.jointplot(x='lotfrontage', y='saleprice', data=train, kind="reg")

# %%
# Joint Distribution Plot of firstflrsf
sns.jointplot(x='firstflrsf', y='saleprice', data=train, kind="reg")

# %%
# Joint Distribution Plot of totalbsmtsf
sns.jointplot(x='totalbsmtsf', y='saleprice', data=train, kind="reg")

# %%
# How expensive are houses?
print('The cheapest house sold for ${:,.0f} and the most expensive for ${:,.0f}'.format(
    train.saleprice.min(), train.saleprice.max()))
print('The average sales price is ${:,.0f}, while median is ${:,.0f}'.format(
    train.saleprice.mean(), train.saleprice.median()))
train.saleprice.hist(bins=75, rwidth=.8, figsize=(14,4))
plt.title('How expensive are houses?')
plt.show()
# Out:
# The cheapest house sold for $34,900 and the most expensive for $625,000
# The average sales price is $179,098, while median is $160,000

# %%
print('Skew: {:.3f} | Kurtosis: {:.3f}'.format(
    train.saleprice.skew(), train.saleprice.kurtosis()))
# Out:
# Skew: 1.658 | Kurtosis: 4.249

# %%
print('')
print('----- EDA of Train Data: Discrete Variable Analysis -----')
print('')
# Out:
# ----- EDA of Train Data: Discrete Variable Analysis -----

# %%
#EDA Discrete Variable Analysis (Categorical)
#Boxplots of the response variable saleprice vs predictor variables
sns.boxplot(x="garagecars", y="saleprice", data=train).set_title('Sale Price vs Garage Cars')
# Out:
# Text(0.5,1,'Sale Price vs Garage Cars')

# %%
sns.boxplot(x="exterqual", y="saleprice", data=train).set_title('Sale Price vs Exterior Quality')
# Out:
# Text(0.5,1,'Sale Price vs Exterior Quality')

# %%
sns.boxplot(x="kitchenqual", y="saleprice", data=train).set_title('Sale Price vs Kitchen Quality')
# Out:
# Text(0.5,1,'Sale Price vs Kitchen Quality')

# %%
sns.boxplot(x="bldgtype", y="saleprice", data=train).set_title('Sale Price vs Building Type')
# Out:
# Text(0.5,1,'Sale Price vs Building Type')

# %%
# When were the houses built?
print('Oldest house built in {}. Newest house built in {}.'.format(
    train.yearbuilt.min(), train.yearbuilt.max()))
train.yearbuilt.hist(bins=14, rwidth=.9, figsize=(12,4))
plt.title('When were the houses built?')
plt.show()
# Out:
# Oldest house built in 1872. Newest house built in 2010.

# %%
train.groupby(['yrsold','mosold']).index.count().plot(kind='bar', figsize=(14,4))
plt.title('When were houses sold?')
plt.show()
# Out:
#   File "<ipython-input-1-2f9644982f13>", line 1
#     train.groupby(['yrsold','mosold']).index.count().plot(kind='bar', figsize=(14,4),edgecolor='blue'))
#                                                                                                       ^
# SyntaxError: invalid syntax

# %%
#Distribution Plot (Histogram of saleprice vs mosold)
#Histogram confirms seasonality in saleprice vs mosold
sns.distplot(train.mosold).set_title('What month were houses sold?')
# Out:
# Text(0.5,1,'What month were houses sold?')

# %%
# Where are houses?
train.groupby('neighborhood').index.count().\
    sort_values().\
    plot(kind='barh', figsize=(6,6))
plt.title('What neighborhoods are houses in?')
plt.show()

# %%
print('')
print('----- Data Cleansing Before Regression -----')
print('')
# Out:
# ----- Data Cleansing Before Regression -----

# %%
# *BONUS* ADD NEW VARIABLES FOR ANALYSIS

# Total number of bathrooms (train)
train["totalbath"] = train["bsmtfullbath"] + (0.5 * train["bsmthalfbath"]) + \
train["fullbath"] + (0.5 * train["halfbath"])
# Total number of bathrooms (test)
test["totalbath"] = test["bsmtfullbath"] + (0.5 * test["bsmthalfbath"]) + \
test["fullbath"] + (0.5 * test["halfbath"])
# Total SF for house (train)
train["totalsf"] = train["grlivarea"] + train["totalbsmtsf"]
# Total SF for house (test)
test["totalsf"] = test["grlivarea"] + test["totalbsmtsf"]

# %%
#Replace 0 values with medians in train data
train1 = train
m = np.median(train1.grlivarea[train1.grlivarea>0])
train1=train1.replace({'grlivarea': {0: m}})

# %%
# Find most important features relative to target
print("Find most important features relative to target")
corr = train.corr()
corr.sort_values(["saleprice"], ascending = False, inplace = True)
print(corr.saleprice)
# Out:
# Find most important features relative to target
# saleprice        1.000000
# totalsf          0.823339
# overallqual      0.805048
# grlivarea        0.716562
# exterqual        0.699112
#                    ...
# overallcond     -0.108835
# kitchenabvgr    -0.110359
# enclosedporch   -0.133619
# fence           -0.166548
# lotshape        -0.289179
# Name: saleprice, Length: 60, dtype: float64

# %%
#Create a heatmap to check for correlated variables
# Compute the correlation matrix
corr = train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, vmin=-1, center=0,
        square=True, linewidths=1, xticklabels = True, yticklabels = True, cbar_kws={"shrink": .5})

# %%
#Run a simple model#Find the best single variable model
#model = smf.ols(formula='saleprice ~ grlivarea' , data=train1).fit()  

#print (model.summary())

# %%
#Find the best single variable model
lm = smf.ols(formula='saleprice ~ overallqual' , data=train1).fit()  
  
print (lm.summary())
print (lm.params)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.648
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     3746.
# Date:                Sun, 08 Jul 2018   Prob (F-statistic):               0.00
# Time:                        20:49:14   Log-Likelihood:                -24761.
# No. Observations:                2036   AIC:                         4.953e+04
# Df Residuals:                    2034   BIC:                         4.954e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -9.333e+04   4567.820    -20.432      0.000   -1.02e+05   -8.44e+04
# overallqual  4.486e+04    733.022     61.205      0.000    4.34e+04    4.63e+04
# ==============================================================================
# Omnibus:                      534.698   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2495.956
# Skew:                           1.175   Prob(JB):                         0.00
# Kurtosis:                       7.889   Cond. No.                         28.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept     -93329.999676
# overallqual    44864.771442
# dtype: float64

# %%
#Second best single variable model
lm1 = smf.ols(formula='saleprice ~ totalsf' , data=train1).fit()  
  
print (lm1.summary())
print (lm1.params)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.678
# Method:                 Least Squares   F-statistic:                     4281.
# Date:                Sun, 08 Jul 2018   Prob (F-statistic):               0.00
# Time:                        20:49:15   Log-Likelihood:                -24671.
# No. Observations:                2036   AIC:                         4.935e+04
# Df Residuals:                    2034   BIC:                         4.936e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.683e+04   3443.328    -10.697      0.000   -4.36e+04   -3.01e+04
# totalsf       85.6881      1.310     65.426      0.000      83.120      88.257
# ==============================================================================
# Omnibus:                      165.321   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              913.339
# Skew:                           0.110   Prob(JB):                    4.69e-199
# Kurtosis:                       6.274   Cond. No.                     9.22e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept   -36833.181364
# totalsf         85.688099
# dtype: float64

# %%
#Find the best two variable regression model
lm2 = smf.ols(formula='saleprice ~ grlivarea + overallqual', data=train1).fit()
#print(lm.params) 
  
print (lm2.summary())
print (lm2.params)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     3006.
# Date:                Sun, 08 Jul 2018   Prob (F-statistic):               0.00
# Time:                        20:49:15   Log-Likelihood:                -24424.
# No. Observations:                2036   AIC:                         4.885e+04
# Df Residuals:                    2033   BIC:                         4.887e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1.121e+05   3928.553    -28.541      0.000    -1.2e+05   -1.04e+05
# grlivarea      62.4080      2.209     28.249      0.000      58.075      66.740
# overallqual  3.275e+04    755.019     43.373      0.000    3.13e+04    3.42e+04
# ==============================================================================
# Omnibus:                      476.731   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3077.560
# Skew:                           0.940   Prob(JB):                         0.00
# Kurtosis:                       8.722   Cond. No.                     7.09e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     -112123.992146
# grlivarea          62.407952
# overallqual     32747.170019
# dtype: float64

# %%
#Find the best multiple regression model
model = smf.ols(formula='saleprice ~ overallqual + grlivarea + neighborhood + yearbuilt', data=train1).fit()
  
print (model.summary())
print (model.params)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     310.6
# Date:                Sun, 08 Jul 2018   Prob (F-statistic):               0.00
# Time:                        20:49:15   Log-Likelihood:                -24090.
# No. Observations:                2036   AIC:                         4.824e+04
# Df Residuals:                    2006   BIC:                         4.841e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept               -1.049e+06   1.08e+05     -9.716      0.000   -1.26e+06   -8.37e+05
# neighborhood[T.Blueste] -1.473e+04    1.5e+04     -0.982      0.326   -4.41e+04    1.47e+04
# neighborhood[T.BrDale]  -3.175e+04   1.11e+04     -2.870      0.004   -5.34e+04   -1.01e+04
# neighborhood[T.BrkSide]   1.41e+04   9570.992      1.473      0.141   -4672.142    3.29e+04
# neighborhood[T.ClearCr]  2.983e+04   1.03e+04      2.891      0.004    9595.375    5.01e+04
# neighborhood[T.CollgCr]  9718.6105   8306.049      1.170      0.242   -6570.775     2.6e+04
# neighborhood[T.Crawfor]   3.87e+04   9347.620      4.140      0.000    2.04e+04     5.7e+04
# neighborhood[T.Edwards]  7510.7944   8821.493      0.851      0.395   -9789.452    2.48e+04
# neighborhood[T.Gilbert] -5706.6837   8573.644     -0.666      0.506   -2.25e+04    1.11e+04
# neighborhood[T.Greens]   3441.8720   1.59e+04      0.216      0.829   -2.78e+04    3.47e+04
# neighborhood[T.GrnHill]  1.312e+05   3.45e+04      3.807      0.000    6.36e+04    1.99e+05
# neighborhood[T.IDOTRR]   7790.3339   9972.554      0.781      0.435   -1.18e+04    2.73e+04
# neighborhood[T.MeadowV] -1.201e+04   1.08e+04     -1.116      0.264   -3.31e+04    9088.802
# neighborhood[T.Mitchel]  1.284e+04   8924.145      1.439      0.150   -4656.674    3.03e+04
# neighborhood[T.NAmes]    1.342e+04   8535.678      1.572      0.116   -3320.807    3.02e+04
# neighborhood[T.NPkVill] -1.762e+04   1.15e+04     -1.538      0.124   -4.01e+04    4841.871
# neighborhood[T.NWAmes]   2320.4115   8891.280      0.261      0.794   -1.51e+04    1.98e+04
# neighborhood[T.NoRidge]  4.658e+04   9467.377      4.920      0.000     2.8e+04    6.51e+04
# neighborhood[T.NridgHt]  6.792e+04   8609.085      7.890      0.000     5.1e+04    8.48e+04
# neighborhood[T.OldTown]  5703.9225   9375.483      0.608      0.543   -1.27e+04    2.41e+04
# neighborhood[T.SWISU]   -4616.2185    1.1e+04     -0.420      0.674   -2.62e+04    1.69e+04
# neighborhood[T.Sawyer]   1.487e+04   8919.364      1.667      0.096   -2622.658    3.24e+04
# neighborhood[T.SawyerW] -4735.5869   8745.350     -0.541      0.588   -2.19e+04    1.24e+04
# neighborhood[T.Somerst]  1.282e+04   8465.224      1.514      0.130   -3784.767    2.94e+04
# neighborhood[T.StoneBr]  6.225e+04   9963.308      6.248      0.000    4.27e+04    8.18e+04
# neighborhood[T.Timber]   3.364e+04   9072.524      3.708      0.000    1.59e+04    5.14e+04
# neighborhood[T.Veenker]  3.045e+04   1.21e+04      2.522      0.012    6771.370    5.41e+04
# overallqual              2.062e+04    903.963     22.808      0.000    1.88e+04    2.24e+04
# grlivarea                  61.1679      2.071     29.529      0.000      57.106      65.230
# yearbuilt                 506.3192     54.272      9.329      0.000     399.884     612.754
# ==============================================================================
# Omnibus:                      572.129   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5248.909
# Skew:                           1.053   Prob(JB):                         0.00
# Kurtosis:                      10.579   Cond. No.                     3.63e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.63e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept                 -1.049060e+06
# neighborhood[T.Blueste]   -1.473050e+04
# neighborhood[T.BrDale]    -3.174742e+04
# neighborhood[T.BrkSide]    1.409798e+04
# neighborhood[T.ClearCr]    2.983078e+04
#                                ...
# neighborhood[T.Timber]     3.364386e+04
# neighborhood[T.Veenker]    3.044692e+04
# overallqual                2.061788e+04
# grlivarea                  6.116792e+01
# yearbuilt                  5.063192e+02
# Length: 30, dtype: float64

# %%
#Multiple regression with new variable totalsf
lm4 = smf.ols(formula='saleprice ~ overallqual + totalsf + neighborhood + yearbuilt', data=train1).fit()
#print(lm.params) 
  
print (lm4.summary())
print (lm4.params)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     359.9
# Date:                Sun, 08 Jul 2018   Prob (F-statistic):               0.00
# Time:                        20:49:15   Log-Likelihood:                -23966.
# No. Observations:                2036   AIC:                         4.799e+04
# Df Residuals:                    2006   BIC:                         4.816e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                -7.57e+05   1.01e+05     -7.507      0.000   -9.55e+05   -5.59e+05
# neighborhood[T.Blueste]  5931.7895   1.41e+04      0.420      0.675   -2.18e+04    3.36e+04
# neighborhood[T.BrDale]  -9356.7529   1.04e+04     -0.897      0.370   -2.98e+04    1.11e+04
# neighborhood[T.BrkSide]  2.012e+04   9006.109      2.234      0.026    2456.104    3.78e+04
# neighborhood[T.ClearCr]  3.318e+04   9690.136      3.424      0.001    1.42e+04    5.22e+04
# neighborhood[T.CollgCr]   1.54e+04   7807.885      1.972      0.049      86.616    3.07e+04
# neighborhood[T.Crawfor]  4.529e+04   8776.311      5.160      0.000    2.81e+04    6.25e+04
# neighborhood[T.Edwards]  1.638e+04   8293.928      1.975      0.048     118.656    3.26e+04
# neighborhood[T.Gilbert]  1.489e+04   8034.319      1.854      0.064    -863.655    3.06e+04
# neighborhood[T.Greens]   8401.9926    1.5e+04      0.560      0.575    -2.1e+04    3.78e+04
# neighborhood[T.GrnHill]  1.214e+05   3.24e+04      3.742      0.000    5.78e+04    1.85e+05
# neighborhood[T.IDOTRR]   1.321e+04   9382.469      1.408      0.159   -5192.681    3.16e+04
# neighborhood[T.MeadowV]  5392.3064   1.01e+04      0.533      0.594   -1.45e+04    2.52e+04
# neighborhood[T.Mitchel]  1.571e+04   8391.558      1.872      0.061    -751.377    3.22e+04
# neighborhood[T.NAmes]    1.217e+04   8030.651      1.515      0.130   -3581.409    2.79e+04
# neighborhood[T.NPkVill] -7465.4282   1.08e+04     -0.693      0.489   -2.86e+04    1.37e+04
# neighborhood[T.NWAmes]   5566.1050   8353.270      0.666      0.505   -1.08e+04    2.19e+04
# neighborhood[T.NoRidge]  5.521e+04   8832.750      6.250      0.000    3.79e+04    7.25e+04
# neighborhood[T.NridgHt]  6.241e+04   8106.561      7.699      0.000    4.65e+04    7.83e+04
# neighborhood[T.OldTown]  1.185e+04   8816.377      1.344      0.179   -5438.934    2.91e+04
# neighborhood[T.SWISU]    3183.4676   1.03e+04      0.309      0.758    -1.7e+04    2.34e+04
# neighborhood[T.Sawyer]   1.559e+04   8390.776      1.858      0.063    -864.043     3.2e+04
# neighborhood[T.SawyerW]  7078.0865   8209.599      0.862      0.389   -9022.147    2.32e+04
# neighborhood[T.Somerst]  2.188e+04   7956.501      2.750      0.006    6275.769    3.75e+04
# neighborhood[T.StoneBr]  5.703e+04   9378.916      6.080      0.000    3.86e+04    7.54e+04
# neighborhood[T.Timber]   3.291e+04   8532.473      3.857      0.000    1.62e+04    4.96e+04
# neighborhood[T.Veenker]  2.547e+04   1.14e+04      2.242      0.025    3185.622    4.77e+04
# overallqual              1.793e+04    866.323     20.702      0.000    1.62e+04    1.96e+04
# totalsf                    47.8522      1.356     35.293      0.000      45.193      50.511
# yearbuilt                 348.5100     50.684      6.876      0.000     249.111     447.909
# ==============================================================================
# Omnibus:                      465.037   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3766.138
# Skew:                           0.844   Prob(JB):                         0.00
# Kurtosis:                       9.445   Cond. No.                     4.73e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept                 -756969.914606
# neighborhood[T.Blueste]      5931.789460
# neighborhood[T.BrDale]      -9356.752882
# neighborhood[T.BrkSide]     20118.411466
# neighborhood[T.ClearCr]     33178.863181
#                                ...
# neighborhood[T.Timber]      32908.224576
# neighborhood[T.Veenker]     25466.454839
# overallqual                 17934.565153
# totalsf                        47.852181
# yearbuilt                     348.509963
# Length: 30, dtype: float64

# %%
#dir(model) lists other print options
#Use the model to score ames_test_sfam
predictions = model.fittedvalues
print(test)
print(predictions)
# Out:
#      index  p_saleprice  saleprice  subclass zoning  lotfrontage  lotarea street alley lotshape landcontour utilities  \
# 0        1          NaN        NaN        30      C         69.0    12366   Pave   NaN      Reg         Lvl    AllPub
# 1        4          NaN        NaN        20     FV         65.0     8125   Pave   NaN      Reg         Lvl    AllPub
# 2        7          NaN        NaN        60     RL         80.0     9760   Pave   NaN      Reg         Lvl    AllPub
# 3       11          NaN        NaN        20     RL         76.0    10141   Pave   NaN      IR1         Lvl    AllPub
# 4       13          NaN        NaN        20     RL        103.0    11175   Pave   NaN      IR1         Lvl    AllPub
# ..     ...          ...        ...       ...    ...          ...      ...    ...   ...      ...         ...       ...
# 721   2912          NaN        NaN        80     RL          NaN    12800   Pave   NaN      Reg         Low    AllPub
# 722   2914          NaN        NaN        60     RL        118.0    13654   Pave   NaN      IR1         Lvl    AllPub
# 723   2919          NaN        NaN        20     RL         80.0     9600   Pave   NaN      Reg         Lvl    AllPub
# 724   2923          NaN        NaN        20     RL         80.0    10400   Pave   NaN      Reg         Lvl    AllPub
# 725   2924          NaN        NaN        30     RL          NaN    25339   Pave   NaN      Reg         Lvl    AllPub
#
#     lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual   ...     garagearea  \
# 0      Inside       Gtl       IDOTRR      Feedr       Norm     1Fam     1Story            3   ...            0.0
# 1      Corner       Gtl      Somerst       Norm       Norm     1Fam     1Story            8   ...          517.0
# 2      Inside       Mod        NAmes       Norm       Norm     1Fam     2Story            6   ...          440.0
# 3      Inside       Gtl      SawyerW       Norm       Norm     1Fam     1Story            8   ...          845.0
# 4      Corner       Gtl      CollgCr       Norm       Norm     1Fam     1Story            7   ...          440.0
# ..        ...       ...          ...        ...        ...      ...        ...          ...   ...            ...
# 721    Inside       Mod      SawyerW       Norm       Norm     1Fam       SLvl            7   ...          569.0
# 722   CulDSac       Gtl      NridgHt       Norm       Norm     1Fam     2Story            9   ...          814.0
# 723    Inside       Gtl       NWAmes       Norm       Norm     1Fam     1Story            7   ...          528.0
# 724    Inside       Gtl       NWAmes       Norm       Norm     1Fam     1Story            7   ...          530.0
# 725    Inside       Gtl       Sawyer       Norm       Norm     1Fam     1Story            5   ...          576.0
#
#      garagequal  garagecond paveddrive wooddecksf openporchsf enclosedporch threessnporch  screenporch poolarea  \
# 0           NaN         NaN          N          0           0            23             0            0        0
# 1            TA          TA          Y          0         175             0             0            0        0
# 2            TA          TA          Y        239          42             0             0            0        0
# 3            TA          TA          Y        210          36             0             0            0        0
# 4            TA          TA          Y          0          20             0             0            0        0
# ..          ...         ...        ...        ...         ...           ...           ...          ...      ...
# 721          TA          TA          Y         80           0             0             0          396        0
# 722          TA          TA          Y        282          55             0             0            0        0
# 723          TA          TA          Y          0           0             0             0            0        0
# 724          TA          TA          Y         98           0             0             0            0        0
# 725          TA          TA          N          0           0           112             0            0        0
#
#     poolqc  fence miscfeature miscval mosold yrsold  saletype salecondition  totalbath  totalsf
# 0      NaN    NaN         NaN       0     10   2006        WD       Abnorml        1.0      729
# 1      NaN    NaN         NaN       0     10   2009       New       Partial        2.0     3672
# 2      NaN   MnWw         NaN       0      7   2007        WD        Normal        2.5     2673
# 3      NaN    NaN         NaN       0      1   2009        WD        Normal        2.0     3024
# 4      NaN    NaN         NaN       0     10   2007       New       Partial        2.0     2632
# ..     ...    ...         ...     ...    ...    ...       ...           ...        ...      ...
# 721    NaN    NaN         NaN       0      8   2009        WD        Normal        3.5     3162
# 722    NaN    NaN         NaN       0      5   2007        WD        Normal        2.5     4462
# 723    NaN    NaN         NaN       0      7   2006       COD        Normal        1.5     2328
# 724    NaN  MnPrv         NaN       0      5   2008        WD        Normal        2.0     2986
# 725    NaN    NaN         NaN       0      8   2007        WD        Normal        2.0     2232
#
# [726 rows x 84 columns]
# 0       248114.891380
# 1       193396.890554
# 2       105377.154950
# 3       196830.786965
# 4       158321.938055
#             ...
# 2034    152125.944439
# 2035    150091.751743
# 2036    161842.631797
# 2037    118884.545547
# 2038    273643.252922
# Length: 2036, dtype: float64

# %%
#Convert the array predictions to a data frame then merge with the index for the test data to create your file
test_predictions = model.predict(test)
print(test_predictions)
d = {'p_saleprice': test_predictions}
df1 = test[['index']]
df2=pd.DataFrame(data=d)
your_file = pd.concat([df1,df2],axis = 1, join_axes=[df1.index])
print(your_file)
# Out:
# 0       49966.523378
# 1      257693.359512
# 2      195699.210103
# 3      218297.304479
# 4      201663.668897
#            ...
# 721    198158.805541
# 722    388295.682711
# 723    165727.817497
# 724    197919.121069
# 725    126633.217967
# Length: 726, dtype: float64
#      index    p_saleprice
# 0        1   49966.523378
# 1        4  257693.359512
# 2        7  195699.210103
# 3       11  218297.304479
# 4       13  201663.668897
# ..     ...            ...
# 721   2912  198158.805541
# 722   2914  388295.682711
# 723   2919  165727.817497
# 724   2923  197919.121069
# 725   2924  126633.217967
#
# [726 rows x 2 columns]

# %%
#Submit your file as csv using the following code to save on your computer
#You will have to delete the first column in the csv file to submit to kaggle 
your_file.to_csv('/Users/rmorlows/Desktop/MSDS410/Assignment 01/hw01_predictions.csv')
